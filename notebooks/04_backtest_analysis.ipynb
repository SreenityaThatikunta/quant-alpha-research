# %% [markdown]
# # Backtest analysis
# Construct weekly portfolios from OOS predictions and inspect net performance, turnover, and exposures.

# %%
from src.portfolio import construct_portfolio, exposure_diagnostics
from src.backtest import run_weekly_backtest
weights = construct_portfolio(oos_predictions)
backtest = run_weekly_backtest(weights, oos_predictions)
(1 + backtest.set_index('date').net_return).cumprod().plot(title='Net cumulative return')
