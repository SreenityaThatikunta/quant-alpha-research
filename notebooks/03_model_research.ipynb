# %% [markdown]
# # Walk-forward model research
# Compare Ridge and XGBoost strictly using concatenated out-of-sample predictions.

# %%
from src.models import walk_forward_predictions
from src.metrics import prediction_metrics
predictions = walk_forward_predictions(eligible_panel, feature_columns, model_name='ridge')
daily_ic, summary = prediction_metrics(predictions)
summary
